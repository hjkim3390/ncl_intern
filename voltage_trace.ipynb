# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
def visualize(filename):
    df = pd.read_csv(filename)
    plt.plot(df['voltage_trace'].tolist())

# %%
visualize('cell_0_v.csv')

# %%
def visualize_average_voltage(filename):
    df = pd.read_csv(filename)
    for col in df.columns[1:]:
        df[col]
    plt.plot(df['voltage_trace'].tolist())

# %%
df = pd.read_csv('cell_voltage.csv')

# %%
average_per_column = df.mean(axis=0)

# %%
plt.hist(average_per_column.tolist(), bins = 30)
# Out:
# (array([  1.,   0.,   0.,   0.,   0.,   0.,   0.,   3.,   1.,   4.,   4.,
#           8.,  13.,  14.,  23.,  61.,  48.,  69.,  91., 119., 172., 229.,
#         263., 284., 260., 175., 109.,  43.,   5.,   1.]),
#  array([-65.45486308, -65.22284795, -64.99083282, -64.75881769,
#         -64.52680256, -64.29478744, -64.06277231, -63.83075718,
#         -63.59874205, -63.36672692, -63.13471179, -62.90269667,
#         -62.67068154, -62.43866641, -62.20665128, -61.97463615,
#         -61.74262103, -61.5106059 , -61.27859077, -61.04657564,
#         -60.81456051, -60.58254538, -60.35053026, -60.11851513,
#         -59.8865    , -59.65448487, -59.42246974, -59.19045462,
#         -58.95843949, -58.72642436, -58.49440923]),
#  <BarContainer object of 30 artists>)

# %%
df = pd.read_csv('cell_voltage.csv')

# %%
plt.plot(df['cell_5'])
