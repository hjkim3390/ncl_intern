# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
def visualize(filename):
    df = pd.read_csv(filename)
    plt.vlines(df['spike_timing'].tolist(), 0, 1)

# %%
visualize('precell_spiking.csv')
