# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
def visualize(filename):
    df = pd.read_csv(filename)
    plt.plot(df['voltage_trace'].tolist())

# %%
visualize('precell_voltage.csv')
